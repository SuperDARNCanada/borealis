# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import matplotlib
sys.path.append('../../../experiments/')
import test_decimation_schemes
from test_decimation_schemes import *

# %%
sys.path.append('../testing_utils/')
from filter_tools.filter_tools import plot_filter_response, plot_cascaded_filters_response

# %%
scheme = create_test_scheme_8()
s_per_samples = [1.0/stage.input_rate for stage in scheme.stages]
num_taps = [len(stage.filter_taps) for stage in scheme.stages]
filter_times = [num * s_per_sample for num, s_per_sample in zip(num_taps, s_per_samples)]
print(filter_times)
# Out:
# 496
# 104
# 27
# 4
# [9.92e-05, 0.000208, 0.00027, 0.00023999999999999998]

# %%
all_taps = [stage.filter_taps for stage in scheme.stages]
all_sample_rates = [stage.input_rate for stage in scheme.stages]
plot_cascaded_filters_response(all_taps, all_sample_rates, xlim=[0,5000])
# Out:
# (5120,) (5120,)
# (25600,) (25600,)
# (153600,) (153600,)
# ../testing_utils/filter_tools/filter_tools.py:228: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(xf, 20 * np.log10(abs(fft_to_plot)), 'b')

# %%
plot_filter_response(scheme.stages[0].filter_taps, 'Stage 0', 5.0e6)

# %%
plot_filter_response(scheme.stages[1].filter_taps, 'Stage 1', 500.0e3)

# %%
plot_filter_response(scheme.stages[2].filter_taps, 'Stage 2', 250.0e3/3)

# %%
plot_filter_response(scheme.stages[3].filter_taps, 'Stage 3', 10.0e3)
