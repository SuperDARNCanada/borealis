# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import matplotlib
sys.path.append('../../../experiments/')
import test_decimation_schemes
from test_decimation_schemes import create_test_scheme_1, create_test_scheme_2, create_test_scheme_3, create_test_scheme_4

# %%
sys.path.append('../testing_utils/')
from filter_tools.filter_tools import plot_filter_response

# %%
scheme = create_test_scheme_2()
s_per_samples = [1.0/stage.input_rate for stage in scheme.stages]
num_taps = [len(stage.filter_taps) for stage in scheme.stages]
filter_times = [num * s_per_sample for num, s_per_sample in zip(num_taps, s_per_samples)]
print(filter_times)
# Out:
# 215
# 105
# 13
# 2
# [4.2999999999999995e-05, 0.00020999999999999998, 0.00026000000000000003, 0.0002]

# %%
plot_filter_response(scheme.stages[0].filter_taps, 'Stage 0', 5.0e6)

# %%
plot_filter_response(scheme.stages[1].filter_taps, 'Stage 1', 500.0e3)

# %%
plot_filter_response(scheme.stages[2].filter_taps, 'Stage 2', 50.0e3)

# %%
plot_filter_response(scheme.stages[3].filter_taps, 'Stage 3', 10.0e3)
